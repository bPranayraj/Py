# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\HP\Downloads\Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        54.000000      54.000000
# mean          5.692593   78729.259259
# std           2.696388   27486.353849
# min           1.100000   37150.000000
# 25%           3.750000   56957.000000
# 50%           5.050000   66983.500000
# 75%           8.125000  104587.000000
# max          10.500000  126872.000000

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
x= df.iloc[:, :-1].values
y= df.iloc[:,-1 ].values
     

print(x)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]
#  [ 2.9]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 3.9]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.8]
#  [ 5. ]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872,  37150,  48445,
#         51445,  49189,  63218,  58794,  56957,  54081,  63111,  65938,
#         62029,  81088,  87000,  82940,  97738,  98873, 101602, 115812,
#        107431, 108582, 117969, 114635, 120391, 126872], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,  y_train,y_test = train_test_split(x,y, test_size = 0.3, random_state = 10)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(x_test)
predictions
# Out:
# array([ 88780.10476357,  41317.23811639,  91746.53392902,  73947.95893633,
#         53182.95477818,  60104.6228309 ,  69003.91032724, 115477.96725261,
#         91746.53392902,  66037.4811618 , 102623.440869  ,  60104.6228309 ,
#         53182.95477818,  51205.33533455,  79880.81726722,  36373.18950731,
#        116466.77697442])

# %%
y_test
# Out:
# array([ 91738,  43525,  98873,  83088,  48445,  58794,  65938, 116969,
#         98273,  63111, 113812,  63218,  54445,  60150,  87000,  37731,
#        114635], dtype=int64)

# %%
diff = y_test- predictions
diff
# Out:
# array([ 2957.89523643,  2207.76188361,  7126.46607098,  9140.04106367,
#        -4737.95477818, -1310.6228309 , -3065.91032724,  1491.03274739,
#         6526.46607098, -2926.4811618 , 11188.559131  ,  3113.3771691 ,
#         1262.04522182,  8944.66466545,  7119.18273278,  1357.81049269,
#        -1831.77697442])

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, lr.predict(x_train), 'b')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.plot(x_test, y_test, 'r')
plt.plot(x_test, predictions, 'b')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Metrics

# %%
from sklearn import metrics
rmse = np.sqrt(metrics.mean_squared_error(y_test, predictions))
     

rmse
# Out:
# 5462.475122331002

# %% [markdown]
# ### Predicting

# %%
print(lr.predict([[4]]))
# Out:
# [61093.43255271]
